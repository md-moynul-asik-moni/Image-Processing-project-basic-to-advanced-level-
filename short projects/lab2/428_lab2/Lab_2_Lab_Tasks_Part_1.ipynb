# %%
import numpy as np
from skimage import io, color, exposure
import matplotlib.pyplot as plt

# %% [markdown]
# # Task 1

# %%
# Import the "good.jpeg" image
I = io.imread(None)

# normalize the image
I_norm = None 

# perform arithmetic operations (contrast increase/decrease) on the image
I_add = None # increase by 0.5
I_sub = None # decrease by 0.4
I_mul = None # multiply by 2
I_div = None # divide by 3

# %% [markdown]
# # Task 2

# %%
# Import the "land.jpeg" image
I = io.imread(None)

# normalize the image
I_norm = None

# perform contrast stretching on the image
I_stretched = None
